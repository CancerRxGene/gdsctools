# %% [markdown]
# # Reading IC50 file and Genomic Feature File

# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (10,6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from gdsctools import IC50, ic50_test, GenomicFeatures
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# ## IC50

# %%
r = IC50(ic50_test)

# %%
print(r)
# Out:
# Number of drugs: 11
# Number of cell lines: 988
# Percentage of NA 0.206569746043

# %%
data = r.plot_ic50_count()

# %%
data = r.hist()

# %% [markdown]
# ## Genomic Features

# %%
f = GenomicFeatures() # default from the package

# %%
print(f)
# Out:
# Genomic features distribution
# Number of unique tissues 27
# Number of unique features 677 with
# - Mutation: 270
# - CNA (gain): 116
# - CNA (loss): 291

# %%
f.df.iloc[0:3]
# Out:
#           Sample Name Tissue Factor Value  MS-instability Factor Value  \
# COSMIC ID
# 1287381          201T          lung_NSCLC                            0
# 924100          22RV1            prostate                            1
# 910924       23132-87             stomach                            1
#
#            ABCB1_mut  ABL2_mut  ACACA_mut  ACVR1B_mut  ACVR2A_mut  AFF4_mut  \
# COSMIC ID
# 1287381            0         0          0           0           0         0
# 924100             0         0          0           0           0         0
# 910924             0         0          0           0           0         0
#
#            AHCTF1_mut        ...          \
# COSMIC ID                    ...
# 1287381             0        ...
# 924100              0        ...
# 910924              0        ...
#
#            loss_cnaPANCAN415_(B2M,BUB1B,MGA,TP53BP1)  loss_cnaPANCAN416  \
# COSMIC ID
# 1287381                                            0                  0
# ...

# %%
f.plot()
# Out:
# Bladder                     19
# aero dig tract              79
# biliary tract                5
# bone                        39
# breast                      52
# cervix                      15
# endometrium                 11
# kidney                      34
# large intestine             50
# leukemia                    82
# liver                       17
# lung                        22
# lung NSCLC                 111
# lung SCLC                   64
# lymphoma                    69
# myeloma                     18
# nervous system              56
# neuroblastoma               32
# ovary                       43
# pancreas                    32
# prostate                     7
# skin                        58
# soft tissue                 21
# stomach                     29
# testis                       3
# thyroid                     16
# urogenital system other      4
# dtype: float64
