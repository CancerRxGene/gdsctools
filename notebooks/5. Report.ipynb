# %% [markdown]
# # Summary plots and HTML output

# %%
# %matplotlib inline
# %pylab inline
from gdsctools import anova
matplotlib.rcParams['figure.figsize'] = (10,6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##  HTML Report

# %%
from gdsctools import *

# %%
an = ANOVA(ic50_test)

# %%
results = an.anova_all()
# Out:
#  [                  0%                  ] 0 of 11 complete in 0.0 sec[---               9%                  ] 1 of 11 complete in 0.3 sec[------           18%                  ] 2 of 11 complete in 0.5 sec[----------       27%                  ] 3 of 11 complete in 0.7 sec[-------------    36%                  ] 4 of 11 complete in 1.0 sec[-----------------45%                  ] 5 of 11 complete in 1.3 sec[-----------------54%                  ] 6 of 11 complete in 1.5 sec[-----------------63%----              ] 7 of 11 complete in 1.7 sec[-----------------72%-------           ] 8 of 11 complete in 2.0 sec[-----------------81%-----------       ] 9 of 11 complete in 2.2 sec[-----------------90%--------------    ] 10 of 11 complete in 2.4 sec[-----------------100%-----------------] 11 of 11 complete in 2.7 sec

# %%
report = ANOVAReport(an, results)
# Out:
# /home/cokelaer/Work/github/gdsctools/gdsctools/anova_report.py:111: UserWarning: No drug name or target will be populated.You may want to provide a DRUG_DECODE file.
#   warnings.warn("No drug name or target will be populated."

# %%
# This can take a while since it created all HTML and PNG images
# This will be created in a directory called html_gdsc_anova by default
# See settings notebook for details
report.settings.animate = False
report.create_html_pages(onweb=False)
# Out:
# Creating main HTML page in directory html_gdsc_anova
# Creating individual HTML pages for each drug
# Creating individual HTML pages for each feature
# Creating individual HTML pages for each significant association

# %% [markdown]
# ## Manual summary plot

# %%
df = report.drug_summary()

# %%
df = report.feature_summary()

# %%
df = report.get_significant_hits()
# Out:
# /home/cokelaer/miniconda3/envs/py3/lib/python3.5/site-packages/pandas/core/computation/expressions.py:183: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   unsupported[op_str]))

# %%
# you can create an individual HTML page e.g. the MANOVA page
report.create_html_manova()
# Out:
# openning html_gdsc_anova/associations/manova.html
