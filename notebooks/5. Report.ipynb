# %% [markdown]
# # Summary plots and HTML output

# %%
# %matplotlib inline
# %pylab inline
from gdsctools import anova
matplotlib.rcParams['figure.figsize'] = (10,6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##  HTML Report

# %%
from gdsctools import *

# %%
an = ANOVA(ic50_test)
# Out:
# INFO:root:Reading data and building data structures

# %%
results = an.anova_all()
# Out:
#  [-----------------100%-----------------] 11 of 11 complete in 59.2 sec

# %%
report = ANOVAReport(an, results)
# Out:
# WARNING no drug name or target will be populated
# You can read one if you wish using read_drug_decoder

# %%
# This can take a while since it created all HTML and PNG images
# This will be created in a directory called html_gdsc_anova by default
# See settings notebook for details
report.create_html_pages()
# Out:
# Creating main HTML page in directory html_gdsc_anova
# Create summary plots
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/mpld3/mplexporter/exporter.py:82: UserWarning: Blended transforms not yet supported. Zoom behavior may not work as expected.
#   warnings.warn("Blended transforms not yet supported. "
# <class 'gdsctools.anova.ANOVAReport'>
# Nothing done. DrugDecoder file not provided.
#
#
# Creating individual HTML pages for each drug
#  [-----------------100%-----------------] 11 of 11 complete in 18.7 sec
#
# Creating individual HTML pages for each feature
#  [-----------------100%-----------------] 41 of 41 complete in 27.3 sec
#
# Creating individual HTML pages for each association
#  [------           16%                  ] 8 of 49 complete in 43.0 sec
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/pandas/core/index.py:4281: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return np.sum(name == np.asarray(self.names)) > 1
# INFO:root:INFO: no tissue with at least 2 pos and 2 neg found. No image created.
#  [-----------------100%-----------------] 49 of 49 complete in 159.3 sec

# %% [markdown]
# ## Manual summary plot

# %%
df = report.drug_summary()

# %%
df = report.feature_summary()

# %%
df = report.get_significant_hits()
# Out:
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/pandas/computation/expressions.py:190: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   unsupported[op_str]))

# %%
# you can create an individual HTML page e.g. the MANOVA page
report.create_html_manova()

# %%
from easydev import browser

# %%
browser.browse('html_gdsc_anova/manova.html')
# Out:
# openning html_gdsc_anova/manova.html

# %% [markdown]
# <hr>
# <ht>
# **Author: Thomas Cokelaer, Nov 2015**
