# %% [markdown]
# # Draft in progress

# %%
# %matplotlib inline
# %pylab inline
from gdsctools import anova
matplotlib.rcParams['figure.figsize'] = (10,6)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
import matplotlib

# %%
import mpld3
mpld3.enable_notebook()

# %%
ls ../gdsctools/anova_all.tsv
# Out:
# ../gdsctools/anova_all.tsv

# %%
r = anova.ANOVAReport(None, results='../gdsctools/anova_all.tsv', 
                             concentrations='../gdsctools/concentrations.tsv')
# Out:
# Reading the results from a file
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f6a2881dbdd0> in <module>()
#       1 r = anova.ANOVAReport(None, results='../gdsctools/anova_all.tsv',
# ----> 2                              concentrations='../gdsctools/concentrations.tsv')
#
# /home/cokelaer/Work/github/gdsctools/gdsctools/anova.pyc in __init__(self, gdsc, results, concentrations, sep)
#     149
#     150         self.settings = ANOVASettings()
# --> 151         for k, v in gdsc.settings.items():
#     152             self.settings[k] = v
#     153
#
# AttributeError: 'NoneType' object has no attribute 'settings'

# %%
from gdsctools import volcano

# %%
v = volcano.VolcanoANOVA(r.df)

# %%
pylab.figure()
v.volcano_plot_one_drug('Drug_1047_IC50')
pylab.show()
# Out:
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/mpld3/mplexporter/exporter.py:82: UserWarning: Blended transforms not yet supported. Zoom behavior may not work as expected.
#   warnings.warn("Blended transforms not yet supported. "
