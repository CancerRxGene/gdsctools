# %% [markdown]
# Read an IC50 matrix of N drugs by M cell lines and compute association
# between a drug and one of the default features

# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (10,6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from gdsctools import ANOVA, ic50_test

# %%
an = ANOVA(ic50_test)
# Out:
# Reading data
# Creating data structures
# Creating data structures

# %%
an.anova_one_drug_one_feature('Drug_1047_IC50', 'BRAF_mut', 
                              show_boxplot=True)
# Out:
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/pandas/core/index.py:4281: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return np.sum(name == np.asarray(self.names)) > 1
#       Drug Target         Drug id       Drug name   FEATURE  \
# 1  Drug_1047_IC50  Drug_1047_IC50  Drug_1047_IC50  BRAF_mut
#
#    FEATURE_ANOVA_pval  FEATURE_IC50_T_pval  FEATURE_IC50_effect_size  \
# 1            0.004476             0.000045                  0.515504
#
#    FEATURE_deltaMEAN_IC50  FEATUREneg_Glass_delta  FEATUREneg_IC50_sd  \
# 1               -0.692933                0.518655            1.336019
#
#    FEATUREneg_logIC50_MEAN  FEATUREpos_Glass_delta  FEATUREpos_IC50_sd  \
# 1                 3.582493                0.483188            1.434086
#
#    FEATUREpos_logIC50_MEAN  MSI_ANOVA_pval  N_FEATURE_neg  N_FEATURE_pos  \
# 1                  2.88956        0.056162            777             69
#
# ...
