# %% [markdown]
# Read an IC50 matrix of N drugs by M cell lines and compute association
# between a drug and one of the default features

# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (10,6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from gdsctools import ANOVA, ic50_test

# %%
an = ANOVA(ic50_test)
# Out:
# INFO:root:Reading data and building data structures

# %%
an.anova_one_drug_one_feature('Drug_1047_IC50', 'BRAF_mut', 
                              show=True)
# Out:
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/pandas/core/index.py:4281: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return np.sum(name == np.asarray(self.names)) > 1
#           DRUG_ID DRUG_NAME DRUG_TARGET   FEATURE  FEATURE_ANOVA_pval  \
# 1  Drug_1047_IC50      None        None  BRAF_mut            0.004476
#
#    FEATURE_IC50_T_pval  FEATURE_IC50_effect_size  FEATURE_deltaMEAN_IC50  \
# 1             0.000045                  0.515504               -0.692933
#
#    FEATUREneg_Glass_delta  FEATUREneg_IC50_sd  FEATUREneg_logIC50_MEAN  \
# 1                0.518655            1.336019                 3.582493
#
#    FEATUREpos_Glass_delta  FEATUREpos_IC50_sd  FEATUREpos_logIC50_MEAN  \
# 1                0.483188            1.434086                  2.88956
#
#    MSI_ANOVA_pval  N_FEATURE_neg  N_FEATURE_pos  TISSUE_ANOVA_pval  \
# 1        0.056162            777             69       8.916088e-32
#
#   log max.Conc.tested log max.Conc.tested2
# 1                None                 None
