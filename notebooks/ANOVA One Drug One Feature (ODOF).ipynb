# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from gdsctools import anova

# %%
an = anova.GDSC_ANOVA('../gdsctools/ANOVA_input.txt')
# Out:
# Reading data
# Creating data structures

# %%
an.anova_one_drug_one_feature('Drug_1_IC50', 'BRAF_mut', show_boxplot=True)
# Out:
#    Drug Target      Drug id    Drug name   FEATURE  FEATURE_ANOVA_pval  \
# 1  Drug_1_IC50  Drug_1_IC50  Drug_1_IC50  BRAF_mut            0.657098
#
#    FEATURE_IC50_T_pval  FEATURE_IC50_effect_size  FEATURE_deltaMEAN_IC50  \
# 1             0.292449                  0.203809                0.234099
#
#    FEATUREneg_Glass_delta  FEATUREneg_IC50_sd  FEATUREneg_logIC50_MEAN  \
# 1                0.201003            1.164649                  2.42643
#
#    FEATUREpos_Glass_delta  FEATUREpos_IC50_sd  FEATUREpos_logIC50_MEAN  \
# 1                0.252089            0.928633                 2.660528
#
#    MSI_ANOVA_pval  N_FEATURE_neg  N_FEATURE_pos  Tissue_ANOVA_pval  \
# 1        0.145891            346             29           0.000003
#
#   log max.Conc.tested log max.Conc.tested2
# 1                None                 None
