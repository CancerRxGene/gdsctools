# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = (10,6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from gdsctools import anova, ic50_test
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
an = anova.GDSC_ANOVA(ic50_test)
# Out:
# Reading data
# Creating data structures
# Creating data structures

# %%
df = an.anova_one_drug('Drug_1047_IC50')
# Out:
#  [-----------------100%-----------------] 677 of 677 complete in 4.9 sec

# %%
df = an.add_fdr_column(df)

# %%
from gdsctools import volcano_anova

# %%
v = volcano_anova.VolcanoANOVA(df)

# %%
v.volcano_plot_one_drug('Drug_1047_IC50')
